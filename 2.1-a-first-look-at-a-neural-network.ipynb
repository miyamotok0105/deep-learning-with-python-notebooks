# %%
#https://github.com/fchollet/deep-learning-with-python-notebooks/blob/master/2.1-a-first-look-at-a-neural-network.ipynb

# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.1.5'

# %%
from keras.datasets import mnist

(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 3s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %%
from keras import models
from keras import layers

network = models.Sequential()
network.add(layers.Dense(512, activation='relu', input_shape=(28 * 28,)))
network.add(layers.Dense(10, activation='softmax'))

# %%
network.compile(optimizer='rmsprop',
                loss='categorical_crossentropy',
                metrics=['accuracy'])

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255

test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
from keras.utils import to_categorical

train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
network.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 4s 63us/step - loss: 0.2594 - acc: 0.9245
# Epoch 2/5
# 60000/60000 [==============================] - 4s 74us/step - loss: 0.1040 - acc: 0.9688
# Epoch 3/5
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0693 - acc: 0.9793
# Epoch 4/5
# 60000/60000 [==============================] - 4s 72us/step - loss: 0.0497 - acc: 0.9850
# Epoch 5/5
# 31360/60000 [==============>...............] - ETA: 2s - loss: 0.0373 - acc: 0.9896
# 60000/60000 [==============================] - 4s 73us/step - loss: 0.0380 - acc: 0.9887

# %%
test_loss, test_acc = network.evaluate(test_images, test_labels)
# Out:
# 10000/10000 [==============================] - 1s 57us/step

# %%
print('test_acc:', test_acc)
# Out:
# test_acc: 0.9797
